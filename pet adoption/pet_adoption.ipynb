# %% [markdown]
# Train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('train.csv')

# %%
dataset
# Out:
#            pet_id           issue_date  ... breed_category  pet_category
# 0      ANSL_69903  2016-07-10 00:00:00  ...            0.0             1
# 1      ANSL_66892  2013-11-21 00:00:00  ...            0.0             2
# 2      ANSL_69750  2014-09-28 00:00:00  ...            2.0             4
# 3      ANSL_71623  2016-12-31 00:00:00  ...            0.0             2
# 4      ANSL_57969  2017-09-28 00:00:00  ...            0.0             1
# ...           ...                  ...  ...            ...           ...
# 18829  ANSL_51738  2017-01-26 00:00:00  ...            0.0             2
# 18830  ANSL_59900  2016-06-18 00:00:00  ...            2.0             4
# 18831  ANSL_53210  2010-07-21 00:00:00  ...            1.0             1
# 18832  ANSL_63468  2017-05-12 00:00:00  ...            1.0             2
# 18833  ANSL_73558  2011-12-13 00:00:00  ...            1.0             2
#
# [18834 rows x 11 columns]

# %%
dataset.isnull().sum()
# Out:
# pet_id               0
# issue_date           0
# listing_date         0
# condition         1477
# color_type           0
# length(m)            0
# height(cm)           0
# X1                   0
# X2                   0
# breed_category       0
# pet_category         0
# dtype: int64

# %%
 print(dataset['condition'].value_counts())
# Out:
# 1.0    6819
# 0.0    6281
# 2.0    4257
# Name: condition, dtype: int64

# %%
import random
dataset['condition'].fillna(random.randint(0,3),inplace=True)

# %%
print(dataset['condition'])
# Out:
# 0        2.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        2.0
#         ...
# 18829    2.0
# 18830    0.0
# 18831    0.0
# 18832    0.0
# 18833    0.0
# Name: condition, Length: 18834, dtype: float64

# %%
dataset.head()
# Out:
#        pet_id           issue_date  ... breed_category  pet_category
# 0  ANSL_69903  2016-07-10 00:00:00  ...            0.0             1
# 1  ANSL_66892  2013-11-21 00:00:00  ...            0.0             2
# 2  ANSL_69750  2014-09-28 00:00:00  ...            2.0             4
# 3  ANSL_71623  2016-12-31 00:00:00  ...            0.0             2
# 4  ANSL_57969  2017-09-28 00:00:00  ...            0.0             1
#
# [5 rows x 11 columns]

# %%
dataset.head()
# Out:
#        pet_id           issue_date  ... breed_category  pet_category
# 0  ANSL_69903  2016-07-10 00:00:00  ...            0.0             1
# 1  ANSL_66892  2013-11-21 00:00:00  ...            0.0             2
# 2  ANSL_69750  2014-09-28 00:00:00  ...            2.0             4
# 3  ANSL_71623  2016-12-31 00:00:00  ...            0.0             2
# 4  ANSL_57969  2017-09-28 00:00:00  ...            0.0             1
#
# [5 rows x 11 columns]

# %%
dataset['color_type'].value_counts()
# Out:
# Black                4620
# White                2453
# Brown                1791
# Brown Tabby          1687
# Tan                  1349
# Blue                  852
# Orange Tabby          791
# Red                   526
# Brown Brindle         496
# Tricolor              469
# Blue Tabby            386
# Tortie                366
# Calico                343
# Gray                  307
# Chocolate             259
# Torbie                242
# Cream Tabby           191
# Sable                 167
# Cream                 162
# Fawn                  159
# Yellow                143
# Buff                  125
# Lynx Point            117
# Blue Merle            104
# Seal Point             78
# Black Brindle          66
# Gray Tabby             65
# Black Tabby            55
# Flame Point            52
# Brown Merle            39
# Orange                 39
# Black Smoke            32
# Gold                   31
# Tortie Point           26
# Silver                 24
# ...

# %%
dataset.drop(['pet_id'],axis=1)
# Out:
#                 issue_date         listing_date  ...  breed_category pet_category
# 0      2016-07-10 00:00:00  2016-09-21 16:25:00  ...             0.0            1
# 1      2013-11-21 00:00:00  2018-12-27 17:47:00  ...             0.0            2
# 2      2014-09-28 00:00:00  2016-10-19 08:24:00  ...             2.0            4
# 3      2016-12-31 00:00:00  2019-01-25 18:30:00  ...             0.0            2
# 4      2017-09-28 00:00:00  2017-11-19 09:38:00  ...             0.0            1
# ...                    ...                  ...  ...             ...          ...
# 18829  2017-01-26 00:00:00  2018-03-09 15:35:00  ...             0.0            2
# 18830  2016-06-18 00:00:00  2017-07-09 08:37:00  ...             2.0            4
# 18831  2010-07-21 00:00:00  2018-08-22 14:27:00  ...             1.0            1
# 18832  2017-05-12 00:00:00  2018-02-08 14:05:00  ...             1.0            2
# ...

# %%
dataset.corr()
# Out:
#                 condition  length(m)  ...  breed_category  pet_category
# condition        1.000000  -0.011479  ...       -0.548725     -0.138848
# length(m)       -0.011479   1.000000  ...        0.007229     -0.003999
# height(cm)      -0.010947  -0.004464  ...        0.011647      0.001976
# X1               0.190784  -0.002893  ...        0.240729     -0.032594
# X2               0.320893  -0.011175  ...        0.052530     -0.032116
# breed_category  -0.548725   0.007229  ...        1.000000      0.209230
# pet_category    -0.138848  -0.003999  ...        0.209230      1.000000
#
# [7 rows x 7 columns]

# %%
nom=(dataset.groupby('color_type').size())/len(dataset)
nom
# Out:
# color_type
# Agouti               0.000212
# Apricot              0.000690
# Black                0.245301
# Black Brindle        0.003504
# Black Smoke          0.001699
# Black Tabby          0.002920
# Black Tiger          0.000053
# Blue                 0.045237
# Blue Cream           0.000531
# Blue Merle           0.005522
# Blue Point           0.001062
# Blue Smoke           0.000319
# Blue Tabby           0.020495
# Blue Tick            0.001115
# Blue Tiger           0.000531
# Brown                0.095094
# Brown Brindle        0.026335
# Brown Merle          0.002071
# Brown Tabby          0.089572
# Brown Tiger          0.000212
# Buff                 0.006637
# Calico               0.018212
# Calico Point         0.000637
# Chocolate            0.013752
# Chocolate Point      0.000478
# Cream                0.008601
# Cream Tabby          0.010141
# Fawn                 0.008442
# Flame Point          0.002761
# Gold                 0.001646
# ...

# %%
dataset['color']=dataset['color_type'].apply(lambda x: nom[x])

# %%
dataset
# Out:
#            pet_id  issue_date listing_date  ...  pet_category     color  duration
# 0      ANSL_69903  2016-07-10   2016-09-21  ...             1  0.089572        73
# 1      ANSL_66892  2013-11-21   2018-12-27  ...             2  0.130243      1862
# 2      ANSL_69750  2014-09-28   2016-10-19  ...             4  0.095094       752
# 3      ANSL_71623  2016-12-31   2019-01-25  ...             2  0.130243       755
# 4      ANSL_57969  2017-09-28   2017-11-19  ...             1  0.245301        52
# ...           ...         ...          ...  ...           ...       ...       ...
# 18829  ANSL_51738  2017-01-26   2018-03-09  ...             2  0.024902       407
# 18830  ANSL_59900  2016-06-18   2017-07-09  ...             4  0.095094       386
# 18831  ANSL_53210  2010-07-21   2018-08-22  ...             1  0.000637      2954
# 18832  ANSL_63468  2017-05-12   2018-02-08  ...             2  0.071626       272
# ...

# %%
#CBE_encoder=CatBoostEncoder()
#train_cbe=CBE_encoder.fit_transform(dataset['color_type'],dataset['pet_category'])

# %%
dataset
# Out:
#            pet_id           issue_date  ... pet_category     color
# 0      ANSL_69903  2016-07-10 00:00:00  ...            1  0.089572
# 1      ANSL_66892  2013-11-21 00:00:00  ...            2  0.130243
# 2      ANSL_69750  2014-09-28 00:00:00  ...            4  0.095094
# 3      ANSL_71623  2016-12-31 00:00:00  ...            2  0.130243
# 4      ANSL_57969  2017-09-28 00:00:00  ...            1  0.245301
# ...           ...                  ...  ...          ...       ...
# 18829  ANSL_51738  2017-01-26 00:00:00  ...            2  0.024902
# 18830  ANSL_59900  2016-06-18 00:00:00  ...            4  0.095094
# 18831  ANSL_53210  2010-07-21 00:00:00  ...            1  0.000637
# 18832  ANSL_63468  2017-05-12 00:00:00  ...            2  0.071626
# 18833  ANSL_73558  2011-12-13 00:00:00  ...            2  0.095094
#
# [18834 rows x 12 columns]

# %%
dataset.head()
# Out:
#        pet_id           issue_date  ... pet_category     color
# 0  ANSL_69903  2016-07-10 00:00:00  ...            1  0.089572
# 1  ANSL_66892  2013-11-21 00:00:00  ...            2  0.130243
# 2  ANSL_69750  2014-09-28 00:00:00  ...            4  0.095094
# 3  ANSL_71623  2016-12-31 00:00:00  ...            2  0.130243
# 4  ANSL_57969  2017-09-28 00:00:00  ...            1  0.245301
#
# [5 rows x 12 columns]

# %%
dataset.drop(['pet_id'],axis=1)
# Out:
#                 issue_date         listing_date  ...  pet_category     color
# 0      2016-07-10 00:00:00  2016-09-21 16:25:00  ...             1  0.089572
# 1      2013-11-21 00:00:00  2018-12-27 17:47:00  ...             2  0.130243
# 2      2014-09-28 00:00:00  2016-10-19 08:24:00  ...             4  0.095094
# 3      2016-12-31 00:00:00  2019-01-25 18:30:00  ...             2  0.130243
# 4      2017-09-28 00:00:00  2017-11-19 09:38:00  ...             1  0.245301
# ...                    ...                  ...  ...           ...       ...
# 18829  2017-01-26 00:00:00  2018-03-09 15:35:00  ...             2  0.024902
# 18830  2016-06-18 00:00:00  2017-07-09 08:37:00  ...             4  0.095094
# 18831  2010-07-21 00:00:00  2018-08-22 14:27:00  ...             1  0.000637
# 18832  2017-05-12 00:00:00  2018-02-08 14:05:00  ...             2  0.071626
# 18833  2011-12-13 00:00:00  2018-10-26 14:18:00  ...             2  0.095094
#
# [18834 rows x 11 columns]

# %%
dataset['issue_date']=pd.to_datetime(dataset['issue_date']).dt.date
dataset['listing_date']=pd.to_datetime(dataset['listing_date']).dt.date

# %%
dataset
# Out:
#            pet_id  issue_date  ... pet_category     color
# 0      ANSL_69903  2016-07-10  ...            1  0.089572
# 1      ANSL_66892  2013-11-21  ...            2  0.130243
# 2      ANSL_69750  2014-09-28  ...            4  0.095094
# 3      ANSL_71623  2016-12-31  ...            2  0.130243
# 4      ANSL_57969  2017-09-28  ...            1  0.245301
# ...           ...         ...  ...          ...       ...
# 18829  ANSL_51738  2017-01-26  ...            2  0.024902
# 18830  ANSL_59900  2016-06-18  ...            4  0.095094
# 18831  ANSL_53210  2010-07-21  ...            1  0.000637
# 18832  ANSL_63468  2017-05-12  ...            2  0.071626
# 18833  ANSL_73558  2011-12-13  ...            2  0.095094
#
# [18834 rows x 12 columns]

# %%
dataset['duration']=(dataset['listing_date']-dataset['issue_date']).dt.days

# %%
dataset
# Out:
#            pet_id  issue_date listing_date  ...  pet_category     color  duration
# 0      ANSL_69903  2016-07-10   2016-09-21  ...             1  0.089572        73
# 1      ANSL_66892  2013-11-21   2018-12-27  ...             2  0.130243      1862
# 2      ANSL_69750  2014-09-28   2016-10-19  ...             4  0.095094       752
# 3      ANSL_71623  2016-12-31   2019-01-25  ...             2  0.130243       755
# 4      ANSL_57969  2017-09-28   2017-11-19  ...             1  0.245301        52
# ...           ...         ...          ...  ...           ...       ...       ...
# 18829  ANSL_51738  2017-01-26   2018-03-09  ...             2  0.024902       407
# 18830  ANSL_59900  2016-06-18   2017-07-09  ...             4  0.095094       386
# 18831  ANSL_53210  2010-07-21   2018-08-22  ...             1  0.000637      2954
# 18832  ANSL_63468  2017-05-12   2018-02-08  ...             2  0.071626       272
# ...

# %%
new=dataset.drop(['issue_date','listing_date','pet_id','breed_category','pet_category','color_type'],axis=1)

# %%
new
# Out:
#        condition  length(m)  height(cm)  X1  X2     color  duration
# 0            2.0       0.80        7.78  13   9  0.089572        73
# 1            1.0       0.72       14.19  13   9  0.130243      1862
# 2            0.0       0.15       40.90  15   4  0.095094       752
# 3            1.0       0.62       17.82   0   1  0.130243       755
# 4            2.0       0.50       11.06  18   4  0.245301        52
# ...          ...        ...         ...  ..  ..       ...       ...
# 18829        2.0       0.44       27.36   0   1  0.024902       407
# 18830        0.0       0.73       14.25  15   4  0.095094       386
# 18831        0.0       0.99       28.13  13   9  0.000637      2954
# 18832        0.0       0.55       44.82  13   9  0.071626       272
# 18833        0.0       0.86       37.40   0   1  0.095094      2509
#
# [18834 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
new=scale.fit_transform(new)

# %%
new
# Out:
# array([[ 1.52666965,  1.0300209 , -1.51072853, ...,  1.25727915,
#         -0.20638354, -0.71336318],
#        [ 0.2393047 ,  0.75291413, -1.01838767, ...,  1.25727915,
#          0.260066  ,  0.91797474],
#        [-1.04806025, -1.2214716 ,  1.03316059, ..., -0.16411631,
#         -0.14305357, -0.0942025 ],
#        ...,
#        [-1.04806025,  1.68814948,  0.05231929, ...,  1.25727915,
#         -1.22636131,  1.9137383 ],
#        [-1.04806025,  0.16406224,  1.33424892, ...,  1.25727915,
#         -0.41220592, -0.53190077],
#        [-1.04806025,  1.23785098,  0.76433173, ..., -1.01695359,
#         -0.14305357,  1.50795553]])

# %%
label=dataset['breed_category']

# %%
label
# Out:
# 0        0.0
# 1        0.0
# 2        2.0
# 3        0.0
# 4        0.0
#         ...
# 18829    0.0
# 18830    2.0
# 18831    1.0
# 18832    1.0
# 18833    1.0
# Name: breed_category, Length: 18834, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

model=DecisionTreeClassifier(random_state=42)
model.fit(new,label)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %% [markdown]
# test

# %%
test=pd.read_csv('test.csv')

# %%
test
# Out:
#           pet_id           issue_date         listing_date  ...  height(cm)  X1  X2
# 0     ANSL_75005  2005-08-17 00:00:00  2017-09-07 15:35:00  ...       42.73   0   7
# 1     ANSL_76663  2018-11-15 00:00:00  2019-05-08 17:24:00  ...        6.71   0   1
# 2     ANSL_58259  2012-10-11 00:00:00  2018-04-02 16:51:00  ...       41.21   0   7
# 3     ANSL_67171  2015-02-13 00:00:00  2018-04-06 07:25:00  ...        8.46   7   1
# 4     ANSL_72871  2017-01-18 00:00:00  2018-04-26 13:42:00  ...       30.92   0   7
# ...          ...                  ...                  ...  ...         ...  ..  ..
# 8067  ANSL_66809  2016-02-10 00:00:00  2017-03-10 14:56:00  ...       36.08  13   9
# 8068  ANSL_59041  2015-12-07 00:00:00  2018-02-12 00:00:00  ...       27.54  13   9
# 8069  ANSL_60034  2015-12-08 00:00:00  2017-01-04 17:19:00  ...       37.19   0   7
# 8070  ANSL_58066  2016-06-28 00:00:00  2017-07-20 18:19:00  ...       23.83   0   2
# ...

# %%
test_datset=test.drop(['pet_id'],axis=1)

# %%
test.isnull().sum()
# Out:
# pet_id            0
# issue_date        0
# listing_date      0
# condition       619
# color_type        0
# length(m)         0
# height(cm)        0
# X1                0
# X2                0
# dtype: int64

# %%
import random
test['condition'].fillna(random.randint(0,3),inplace=True)

# %%
test.isnull().sum()
# Out:
# pet_id          0
# issue_date      0
# listing_date    0
# condition       0
# color_type      0
# length(m)       0
# height(cm)      0
# X1              0
# X2              0
# dtype: int64

# %%
nom_test=(test.groupby('color_type').size())/len(test)
nom_test
# Out:
# color_type
# Agouti               0.000248
# Apricot              0.000372
# Black                0.242195
# Black Brindle        0.003221
# Black Smoke          0.001239
# Black Tabby          0.003840
# Blue                 0.047448
# Blue Cream           0.000619
# Blue Merle           0.003717
# Blue Point           0.000372
# Blue Smoke           0.000743
# Blue Tabby           0.021184
# Blue Tick            0.002478
# Blue Tiger           0.000124
# Brown                0.099232
# Brown Brindle        0.027502
# Brown Merle          0.002725
# Brown Tabby          0.088206
# Buff                 0.007185
# Calico               0.018831
# Calico Point         0.000619
# Chocolate            0.016477
# Chocolate Point      0.000991
# Cream                0.009663
# Cream Tabby          0.008548
# Fawn                 0.006938
# Flame Point          0.002725
# Gold                 0.001115
# Gray                 0.015981
# Gray Tabby           0.003840
# ...

# %%
test['color']=test['color_type'].apply(lambda x: nom_test[x])

# %%
test['issue_date']=pd.to_datetime(test['issue_date']).dt.date
test['listing_date']=pd.to_datetime(test['listing_date']).dt.date

# %%
test['duration']=(test['listing_date']-test['issue_date']).dt.days

# %%
test
# Out:
#           pet_id  issue_date listing_date  ...  X2     color  duration
# 0     ANSL_75005  2005-08-17   2017-09-07  ...   7  0.242195      4404
# 1     ANSL_76663  2018-11-15   2019-05-08  ...   1  0.041130       174
# 2     ANSL_58259  2012-10-11   2018-04-02  ...   7  0.242195      1999
# 3     ANSL_67171  2015-02-13   2018-04-06  ...   1  0.242195      1148
# 4     ANSL_72871  2017-01-18   2018-04-26  ...   7  0.099232       463
# ...          ...         ...          ...  ...  ..       ...       ...
# 8067  ANSL_66809  2016-02-10   2017-03-10  ...   9  0.099232       394
# 8068  ANSL_59041  2015-12-07   2018-02-12  ...   9  0.072473       798
# 8069  ANSL_60034  2015-12-08   2017-01-04  ...   7  0.242195       393
# 8070  ANSL_58066  2016-06-28   2017-07-20  ...   2  0.242195       387
# 8071  ANSL_69436  2016-02-02   2017-02-28  ...   1  0.242195       392
#
# [8072 rows x 11 columns]

# %%
final_test=test.drop(['pet_id','issue_date','listing_date','color_type'],axis=1)

# %%
final_test=scale.fit_transform(final_test)
final_test
# Out:
# array([[-1.20766125,  1.25255298,  1.18283777, ...,  0.70804005,
#          1.58879833,  3.21481846],
#        [ 0.14120295, -1.54443889, -1.6057133 , ..., -0.99488471,
#         -0.76159927, -0.61801775],
#        [ 0.14120295, -0.92288514,  1.06516432, ...,  0.70804005,
#          1.58879833,  1.03562908],
#        ...,
#        [-1.20766125,  1.63239138,  0.75394902, ...,  0.70804005,
#          1.58879833, -0.41958013],
#        [ 0.14120295,  0.97630687, -0.28033867, ..., -0.71106391,
#          1.58879833, -0.42501678],
#        [-1.20766125,  0.45834541, -0.22769528, ..., -0.99488471,
#          1.58879833, -0.42048624]])

# %%
breed=model.predict(final_test)

# %%
pet=model.predict(final_test)

# %%
submission = pd.DataFrame({"pet_id": test['pet_id'],
                           "breed_category":breed ,
                           "pet_category":pet })
submission.to_csv('submission.csv',index=False)
